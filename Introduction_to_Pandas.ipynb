# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswininridegree/Python-basics-/blob/main/Introduction_to_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Pandas and as well as required Files from the Google Drive

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Reading CSV file for the Pandas Commands

# %%
ds = pd.read_csv('/Credit_Card_Applications.csv')

# %% [markdown]
# Displaying the CSV File

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %% [markdown]
# Knowing about the shape and info of the Dataset

# %%
#Find out the shape - Row size and column size
ds.shape
# Out:
# (690, 16)

# %%
#Give the information related to DataFrames
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %% [markdown]
# Load certain data rows from top to bottom
# Tail() - read and display values from the end

# %%
ds.tail(5)
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13  A14  Class
# 685    0    1      1
# 686    0   45      0
# 687  100    1      1
# 688  120   12      1
# 689  560    1      1

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
idata={'Age':age,'Height':height,'Weight': weight,'Speed': speed}

# %%
idata
# Out:
# {'Age': [64,
#   66,
#   78,
#   85,
#   50,
#   41,
#   57,
#   24,
#   60,
#   19,
#   97,
#   83,
#   85,
#   24,
#   64,
#   63,
#   70,
#   26,
#   51,
#   98,
#   62,
#   62,
#   73,
#   9,
#   41,
#   79,
#   73,
#   59,
#   9,
#   28,
#   29,
#   41,
#   40,
#   36,
#   99,
#   22,
#   7,
#   90,
#   80,
#   81,
#   3,
#   29,
#   84,
#   34,
#   69,
#   41,
#   71,
#   71,
#   44,
#   56,
#   51,
#   5,
#   28,
#   67,
#   13,
#   79,
#   44,
#   91,
#   88,
#   67,
#   0,
#   34,
#   93,
#   28,
#   34,
#   2,
#   69,
#   92,
#   6,
#   40,
#   35,
#   2,
#   10,
#   7,
#   86,
#   74,
#   11,
#   88,
#   35,
#   91,
#   5,
#   10,
#   60,
#   80,
#   19,
#   97,
#   37,
#   27,
#   71,
#   38,
#   5,
#   78,
#   91,
#   36,
#   65,
#   98,
#   85,
#   64,
#   14,
#   96],
#  'Height': [63,
#   61,
#   18,
#   30,
#   73,
#   50,
#   70,
#   53,
#   75,
#   14,
#   93,
#   72,
#   62,
#   75,
#   60,
#   25,
#   79,
#   75,
#   85,
#   30,
#   77,
#   81,
#   16,
#   45,
# ...

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    64      63       3      5
# 1    66      61      39     10
# 2    78      18      97      3
# 3    85      30      55     17
# 4    50      73      50     41
# ..  ...     ...     ...    ...
# 95   98      44      99      9
# 96   85      37      63     20
# 97   64       1      52     36
# 98   14      44      71     66
# 99   96      62      83     76
#
# [100 rows x 4 columns]

# %% [markdown]
# Head() - read and display values from the beginning

# %%
df1.head(10)
# Out:
#    Age  Height  Weight  Speed
# 0   64      63       3      5
# 1   66      61      39     10
# 2   78      18      97      3
# 3   85      30      55     17
# 4   50      73      50     41
# 5   41      50      13     35
# 6   57      70       0     14
# 7   24      53      89     29
# 8   60      75      39     70
# 9   19      14       8      1

# %%
ds.tail(10)
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 680    15790689   1  21.17   0.000   2   8   4  0.500   0   0    0    1    1
# 681    15665181   1  35.25  16.500   1   8   4  4.000   1   0    0    0    2
# 682    15633608   0  22.92  11.585   2  13   4  0.040   1   0    0    0    2
# 683    15805261   0  48.17   1.335   2   3   7  0.335   0   0    0    0    2
# 684    15740356   1  43.00   0.290   1  13   8  1.750   1   1    8    0    2
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 680    0     1      0
# 681   80     1      0
# 682   80  1350      1
# 683    0   121      0
# ...

# %%
ds.describe()
# Out:
#          CustomerID          A1          A2          A3          A4  \
# count  6.900000e+02  690.000000  690.000000  690.000000  690.000000
# mean   1.569047e+07    0.678261   31.568203    4.758725    1.766667
# std    7.150647e+04    0.467482   11.853273    4.978163    0.430063
# min    1.556571e+07    0.000000   13.750000    0.000000    1.000000
# 25%    1.563169e+07    0.000000   22.670000    1.000000    2.000000
# 50%    1.569016e+07    1.000000   28.625000    2.750000    2.000000
# 75%    1.575190e+07    1.000000   37.707500    7.207500    2.000000
# max    1.581544e+07    1.000000   80.250000   28.000000    3.000000
#
#                A5          A6          A7          A8          A9        A10  \
# count  690.000000  690.000000  690.000000  690.000000  690.000000  690.00000
# mean     7.372464    4.692754    2.223406    0.523188    0.427536    2.40000
# std      3.683265    1.992316    3.346513    0.499824    0.495080    4.86294
# ...

# %%
df1['Age']
# Out:
# 0     64
# 1     66
# 2     78
# 3     85
# 4     50
#       ..
# 95    98
# 96    85
# 97    64
# 98    14
# 99    96
# Name: Age, Length: 100, dtype: int64

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    64      63
# 1    66      61
# 2    78      18
# 3    85      30
# 4    50      73
# ..  ...     ...
# 95   98      44
# 96   85      37
# 97   64       1
# 98   14      44
# 99   96      62
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   64      63
# 3   85      30

# %%
df2 = df1[['Age','Height']]

# %%
df2.describe()
# Out:
#               Age      Height
# count  100.000000  100.000000
# mean    51.730000   50.140000
# std     29.806736   26.941395
# min      0.000000    0.000000
# 25%     28.000000   30.000000
# 50%     56.500000   50.500000
# 75%     78.250000   73.250000
# max     99.000000   98.000000

# %%
df1.sort_index(ascending=True)
# Out:
#     Age  Height  Weight  Speed
# 0    64      63       3      5
# 1    66      61      39     10
# 2    78      18      97      3
# 3    85      30      55     17
# 4    50      73      50     41
# ..  ...     ...     ...    ...
# 95   98      44      99      9
# 96   85      37      63     20
# 97   64       1      52     36
# 98   14      44      71     66
# 99   96      62      83     76
#
# [100 rows x 4 columns]

# %%
df1.sort_index(ascending=False)
# Out:
#     Age  Height  Weight  Speed
# 99   96      62      83     76
# 98   14      44      71     66
# 97   64       1      52     36
# 96   85      37      63     20
# 95   98      44      99      9
# ..  ...     ...     ...    ...
# 4    50      73      50     41
# 3    85      30      55     17
# 2    78      18      97      3
# 1    66      61      39     10
# 0    64      63       3      5
#
# [100 rows x 4 columns]

# %%
df2[0::2]
# Out:
#     Age  Height
# 0    64      63
# 2    78      18
# 4    50      73
# 6    57      70
# 8    60      75
# 10   97      93
# 12   85      62
# 14   64      60
# 16   70      79
# 18   51      85
# 20   62      77
# 22   73      16
# 24   41      87
# 26   73      34
# 28    9      35
# 30   29      22
# 32   40       5
# 34   99      82
# 36    7      54
# 38   80      16
# 40    3      67
# 42   84      42
# 44   69      49
# 46   71      84
# 48   44      31
# 50   51      31
# 52   28      75
# 54   13      41
# 56   44      15
# 58   88      42
# 60    0       6
# 62   93      15
# 64   34      80
# 66   69       9
# 68    6      37
# 70   35      52
# 72   10      18
# 74   86       6
# 76   11      81
# 78   35      35
# 80    5      97
# 82   60      74
# 84   19      51
# 86   37      67
# 88   71      65
# 90    5      67
# 92   91      37
# 94   65      41
# 96   85      37
# 98   14      44

# %%
df1[0::2]. describe()
# Out:
#              Age     Height     Weight       Speed
# count  50.000000  50.000000  50.000000   50.000000
# mean   50.300000  50.040000  52.580000   54.240000
# std    29.714457  26.333001  30.809547   28.739903
# min     0.000000   5.000000   0.000000    0.000000
# 25%    28.250000  31.750000  26.750000   35.250000
# 50%    54.000000  50.000000  57.500000   53.000000
# 75%    72.500000  73.750000  75.750000   81.250000
# max    99.000000  97.000000  97.000000  100.000000

# %%
#Filter
filter1 = df1['Weight'] > 50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 2    78      18      97      3
# 3    85      30      55     17
# 7    24      53      89     29
# 12   85      62      61     82
# 15   63      25      80     14
# 17   26      75      77     89
# 19   98      30      81     38
# 20   62      77      74     39
# 22   73      16      69     44
# 25   79      61      53     42
# 28    9      35      95     95
# 30   29      22      85     85
# 31   41      98      84      2
# 32   40       5      58     52
# 34   99      82      97     65
# 35   22      97      55      7
# 36    7      54      58     85
# 37   90      28      65     22
# 38   80      16      82     63
# 39   81      84      86     15
# 41   29      86      52      5
# 45   41      61      71     24
# 46   71      84      86     38
# 47   71      12     100     47
# 48   44      31      96     85
# 52   28      75      93     71
# 55   79       0      95     38
# 58   88      42      74     76
# 60    0       6      78     54
# ...

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 2    78      18      97      3
# 3    85      30      55     17
# 7    24      53      89     29
# 12   85      62      61     82
# 15   63      25      80     14
# 17   26      75      77     89
# 19   98      30      81     38
# 20   62      77      74     39
# 22   73      16      69     44
# 25   79      61      53     42
# 28    9      35      95     95
# 30   29      22      85     85
# 31   41      98      84      2
# 32   40       5      58     52
# 34   99      82      97     65
# 35   22      97      55      7
# 36    7      54      58     85
# 37   90      28      65     22
# 38   80      16      82     63
# 39   81      84      86     15
# 41   29      86      52      5
# 45   41      61      71     24
# 46   71      84      86     38
# 47   71      12     100     47
# 48   44      31      96     85
# 52   28      75      93     71
# 55   79       0      95     38
# 58   88      42      74     76
# 60    0       6      78     54
# ...

# %%
filter2 = df1['Age'] > 50

# %%
df1[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 2    78      18      97      3
# 3    85      30      55     17
# 12   85      62      61     82
# 15   63      25      80     14
# 19   98      30      81     38
# 20   62      77      74     39
# 22   73      16      69     44
# 25   79      61      53     42
# 34   99      82      97     65
# 37   90      28      65     22
# 38   80      16      82     63
# 39   81      84      86     15
# 46   71      84      86     38
# 47   71      12     100     47
# 55   79       0      95     38
# 58   88      42      74     76
# 62   93      15      75     26
# 66   69       9      76     87
# 67   92      64      72     96
# 79   91      49      85     64
# 85   97      10      64      3
# 88   71      65      75     59
# 95   98      44      99      9
# 96   85      37      63     20
# 97   64       1      52     36
# 99   96      62      83     76

# %%
df1.loc[filter1 | filter2]
# Out:
#     Age  Height  Weight  Speed
# 0    64      63       3      5
# 1    66      61      39     10
# 2    78      18      97      3
# 3    85      30      55     17
# 6    57      70       0     14
# ..  ...     ...     ...    ...
# 95   98      44      99      9
# 96   85      37      63     20
# 97   64       1      52     36
# 98   14      44      71     66
# 99   96      62      83     76
#
# [80 rows x 4 columns]
