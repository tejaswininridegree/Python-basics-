# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswininridegree/Python-basics-/blob/main/Random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
df = {
   'grade' : a1,
   'weight' : a2,
   'friends' : a3,
   'cousins' : a4,
   'projects' : a5
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       55      62       10        9        25
# 1       64      58       20        5        29
# 2       94      56       10        9        49
# 3       25      70       12        6        39
# 4       74      54       12        7        42
# ..     ...     ...      ...      ...       ...
# 995     81      64       16       10        50
# 996     35      62       11        9        23
# 997     53      54       18        7        44
# 998     71      58       15       10        20
# 999     56      58       20        8        46
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends     cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean     49.731000    59.898000    14.990000     7.51800    50.508000
# std      28.863051     6.079355     3.131726     1.73571    17.420431
# min       0.000000    50.000000    10.000000     5.00000    20.000000
# 25%      25.000000    55.000000    12.000000     6.00000    35.000000
# 50%      50.000000    60.000000    15.000000     8.00000    51.000000
# 75%      74.000000    65.000000    18.000000     9.00000    65.000000
# max     100.000000    70.000000    20.000000    10.00000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
friend18 = df1['friends']>18

# %%
df1[friend18]
# Out:
#      grade  weight  friends  cousins  projects
# 1       64      58       20        5        29
# 8       23      66       19       10        56
# 14     100      54       20        5        80
# 16      10      55       19        7        26
# 30      55      59       20        8        47
# ..     ...     ...      ...      ...       ...
# 975     86      51       20       10        75
# 980     37      56       19       10        65
# 981     14      58       20        9        68
# 985      0      61       20        8        43
# 999     56      58       20        8        46
#
# [185 rows x 5 columns]

# %%
df1[friend18].describe()
# Out:
#             grade      weight     friends     cousins    projects
# count  185.000000  185.000000  185.000000  185.000000  185.000000
# mean    51.881081   59.989189   19.416216    7.443243   48.913514
# std     29.731533    6.059478    0.494268    1.703025   17.790846
# min      0.000000   50.000000   19.000000    5.000000   20.000000
# 25%     30.000000   55.000000   19.000000    6.000000   32.000000
# 50%     51.000000   59.000000   19.000000    7.000000   50.000000
# 75%     78.000000   66.000000   20.000000    9.000000   63.000000
# max    100.000000   70.000000   20.000000   10.000000   80.000000

# %%
grade98 = df1['grade']>98

# %%
df1[grade98]
# Out:
#      grade  weight  friends  cousins  projects
# 10     100      69       17        8        80
# 14     100      54       20        5        80
# 94     100      57       13        9        31
# 151    100      70       15        9        45
# 172    100      56       14        7        40
# 177    100      57       12        9        60
# 219     99      64       20        7        24
# 234    100      64       19       10        27
# 269     99      55       13        7        64
# 384    100      54       10        5        60
# 397    100      52       15        9        79
# 506    100      55       15        6        61
# 526    100      60       16        5        77
# 560    100      59       15        6        72
# 590    100      69       16        7        30
# 616     99      64       20        9        79
# 626     99      70       20        8        30
# 628    100      64       12        9        55
# 674     99      54       12        9        58
# 677     99      63       16       10        66
# 718     99      70       10        7        56
# 724     99      53       12        7        29
# 784    100      58       20        5        33
# 874    100      64       15        8        68

# %%
df1[friend18&grade98]
# Out:
#      grade  weight  friends  cousins  projects
# 14     100      54       20        5        80
# 219     99      64       20        7        24
# 234    100      64       19       10        27
# 616     99      64       20        9        79
# 626     99      70       20        8        30
# 784    100      58       20        5        33

# %%
df1[friend18 & grade98]['friends']
# Out:
# 14     20
# 219    20
# 234    19
# 616    20
# 626    20
# 784    20
# Name: friends, dtype: int64

# %%
df1[friend18&grade98].count()
# Out:
# grade       6
# weight      6
# friends     6
# cousins     6
# projects    6
# dtype: int64

# %%
df1[friend18&grade98].value_counts
# Out:
# <bound method DataFrame.value_counts of      grade  weight  friends  cousins  projects
# 14     100      54       20        5        80
# 219     99      64       20        7        24
# 234    100      64       19       10        27
# 616     99      64       20        9        79
# 626     99      70       20        8        30
# 784    100      58       20        5        33>

# %%
from matplotlib import pyplot as plt

# %%
df1[friend18 & grade98].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
df1[friend18&grade98].plot()
# Out:
# <Axes: >

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friend18 & grade98].plot(x='grade',y='projects',kind='scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
df1[friend18 & grade98].plot(x=['grade','friends'],y=['projects','weight'],kind='scatter',title='sample Graph')
# Out:
# <Axes: title={'center': 'sample Graph'}, xlabel='[grade, friends]', ylabel='[projects, weight]'>

# %%
df1[friend18 & grade98].plot(x= ['grade','friends'],y= ['projects','weight'],kind='scatter', title='sample graph')
plt.xlabel('x Axis')
plt.ylabel('y Axis')
plt.legend('Test Data')
plt.show()

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
from matplotlib import pyplot as plt

# %%
fdf=df1[friend18 & grade98]

# %%
fdf
# Out:
#      grade  weight  friends  cousins  projects
# 14     100      54       20        5        80
# 219     99      64       20        7        24
# 234    100      64       19       10        27
# 616     99      64       20        9        79
# 626     99      70       20        8        30
# 784    100      58       20        5        33

# %%
df1.to_csv('/mouniData.csv')
